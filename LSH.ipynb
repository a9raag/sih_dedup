# %%
import numpy
import math

# LSH signature generation using random projection
def get_signature(user_vector, rand_proj):
    res = 0
    for p in (rand_proj):
        res = res << 1
        val = numpy.dot(p, user_vector)
        if val >= 0:
            res |= 1
    return res

# %%
# get number of '1's in binary
# running time: O(# of '1's)
def nnz(num):
    if num == 0:
        return 0
    res = 1
    num = num & (num-1)
    while num:
        res += 1
        num = num & (num-1)
    return res

# %%
# angular similarity using definitions
# http://en.wikipedia.org/wiki/Cosine_similarity
def angular_similarity(a,b):
    dot_prod = numpy.dot(a,b)
    sum_a = sum(a**2) **.5
    sum_b = sum(b**2) **.5
    cosine = dot_prod/sum_a/sum_b # cosine similarity
    theta = math.acos(cosine)
    return 1.0-(theta/math.pi)

# %%
def similarity(a,b):
    from sklearn.metrics.pairwise import cosine_similarity
    sim = cosine_similarity(a,b)
    return sim

# %%
def cosine_sim(text1, text2):
    if(type(text1) != str or type(text2)!=str):
        text1 = ' '.join(list(map(lambda x:str(x),text1)))
        text2 = ' '.join(list(map(lambda x:str(x),text2)))
    from sklearn.feature_extraction.text import TfidfVectorizer
    try:
        vectorizer = TfidfVectorizer()
        tfidf = vectorizer.fit_transform([text1, text2])
        return ((tfidf * tfidf.T).A)[0,1]
    except:
        vectorizer = TfidfVectorizer()
        tfidf = vectorizer.fit_transform([text1, text2])
        return ((tfidf * tfidf.T).A)[0,1]

# %%
dim = 200 # number of dimensions per data
d = 2**10 # number of bits per signature

nruns = 24 # repeat times

avg = 0
for run in range(nruns):
    user1 = sorted(numpy.random.randn(dim))
    user2 = sorted(numpy.random.randn(dim))
    randv = numpy.random.randn(d, dim)
    r1 = get_signature(user1, randv)
    r2 = get_signature(user2, randv)
    xor = r1^r2
    true_sim, hash_sim = (angular_similarity(user1, user2), (d-nnz(xor))/float(d))
    diff = abs(hash_sim-true_sim)/true_sim
    avg += diff
    print ('true %.4f, hash %.4f, diff %.4f' % (true_sim, hash_sim, diff))
print ('avg diff' , avg / nruns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-0d975c73ca13> in <module>()
#      12     r2 = get_signature(user2, randv)
#      13     xor = r1^r2
# ---> 14     true_sim, hash_sim = (angular_similarity(user1, user2), (d-nnz(xor))/float(d))
#      15     diff = abs(hash_sim-true_sim)/true_sim
#      16     avg += diff
#
# <ipython-input-15-d1c1d09d6229> in angular_similarity(a, b)
#       3 def angular_similarity(a,b):
#       4     dot_prod = numpy.dot(a,b)
# ----> 5     sum_a = sum(a**2) **.5
#       6     sum_b = sum(b**2) **.5
#       7     cosine = dot_prod/sum_a/sum_b # cosine similarity
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
for i,j in zip(user1,user2):
    print(i,j)
# Out:
# -2.99585988336 -2.30076030264
# -2.88131902946 -2.14486452695
# -2.54749919662 -1.52245026645
# -2.20500747856 -1.48321182274
# -2.06955238331 -1.40175718052
# -1.99912383084 -1.39696441919
# -1.93859714633 -1.35485155212
# -1.91388816948 -1.32573198102
# 1.53022064994 1.69389235748
# 1.57591184785 1.73259480322
# 1.5775488813 1.74728647111
# 1.64353977347 1.77371278197
# 1.68064391291 1.7994348381
# 1.68291679815 1.91887493822
# 1.75752718922 1.99446650025
# 1.84341246898 2.02254477552
# 1.85178434434 2.0381037779
# 1.86473039562 2.34677489147
# 1.92825320388 2.47255720603
# 1.9822531789 2.93603896707
# 2.20559604963 2.95981600763

# %%
import pandas as pd
sample_data = pd.read_csv("csv_example_messy_input.csv")
sample_data.groupby('Address').head()
# Out:
#         Id                                 Source  \
# 0        0  CPS_Early_Childhood_Portal_scrape.csv
# 1        1  CPS_Early_Childhood_Portal_scrape.csv
# 2        2  CPS_Early_Childhood_Portal_scrape.csv
# 3        3  CPS_Early_Childhood_Portal_scrape.csv
# 4        4  CPS_Early_Childhood_Portal_scrape.csv
# 5        5  CPS_Early_Childhood_Portal_scrape.csv
# 6        6  CPS_Early_Childhood_Portal_scrape.csv
# 7        7  CPS_Early_Childhood_Portal_scrape.csv
# 8        8  CPS_Early_Childhood_Portal_scrape.csv
# 9        9  CPS_Early_Childhood_Portal_scrape.csv
# 10      10  CPS_Early_Childhood_Portal_scrape.csv
# 11      11  CPS_Early_Childhood_Portal_scrape.csv
# 12      12  CPS_Early_Childhood_Portal_scrape.csv
# 13      13  CPS_Early_Childhood_Portal_scrape.csv
# 14      14  CPS_Early_Childhood_Portal_scrape.csv
# 15      15  CPS_Early_Childhood_Portal_scrape.csv
# 16      16  CPS_Early_Childhood_Portal_scrape.csv
# 17      17  CPS_Early_Childhood_Portal_scrape.csv
# 18      18  CPS_Early_Childhood_Portal_scrape.csv
# 19      19  CPS_Early_Childhood_Portal_scrape.csv
# 20      20  CPS_Early_Childhood_Portal_scrape.csv
# 21      21  CPS_Early_Childhood_Portal_scrape.csv
# 22      22  CPS_Early_Childhood_Portal_scrape.csv
# 23      23  CPS_Early_Childhood_Portal_scrape.csv
# 24      24  CPS_Early_Childhood_Portal_scrape.csv
# 25      25  CPS_Early_Childhood_Portal_scrape.csv
# 26      26  CPS_Early_Childhood_Portal_scrape.csv
# 27      27  CPS_Early_Childhood_Portal_scrape.csv
# 28      28  CPS_Early_Childhood_Portal_scrape.csv
# 29      29  CPS_Early_Childhood_Portal_scrape.csv
# ...    ...                                    ...
# 3307  3307      purple_binder_early_childhood.csv
# 3308  3308      purple_binder_early_childhood.csv
# 3309  3309      purple_binder_early_childhood.csv
# 3310  3310      purple_binder_early_childhood.csv
# 3311  3311      purple_binder_early_childhood.csv
# 3312  3312      purple_binder_early_childhood.csv
# 3313  3313      purple_binder_early_childhood.csv
# 3314  3314      purple_binder_early_childhood.csv
# 3315  3315      purple_binder_early_childhood.csv
# 3316  3316      purple_binder_early_childhood.csv
# 3317  3317      purple_binder_early_childhood.csv
# 3318  3318      purple_binder_early_childhood.csv
# 3319  3319      purple_binder_early_childhood.csv
# 3320  3320      purple_binder_early_childhood.csv
# 3314           941 E 132nd Street   60627.0  4683055.0  NaN          NaN
# 3315          3003 W Touhy Avenue   60647.0  3427777.0  NaN          NaN
# 3316         1718 S Loomis Street   60608.0  5639796.0  NaN          NaN
# 3317           1347 W Erie Street   60642.0  6663430.0  NaN          NaN
# 3318          4705 S State Street   60609.0        NaN  NaN          NaN
# 3319  4753 W Washington Boulevard   60644.0  3794928.0  NaN          NaN
# 3320          2653 W Ogden Avenue   60608.0  5211196.0  NaN          NaN
# 3321           1900 W Polk Street   60612.0  8646560.0  NaN          NaN
# 3322           234 E 114th Street   60628.0  8404502.0  NaN          NaN
# 3323        1073 W Maxwell Street   60608.0  8297555.0  NaN          NaN
# 3324         1312 S Racine Avenue   60608.0  7466024.0  NaN          NaN
# 3325         2001 W Pierce Street   60622.0  3424499.0  NaN          NaN
# 3326         4339 W McLean Avenue   60639.0        NaN  NaN          NaN
# 3327            624 E 47th Street   60653.0  2682685.0  NaN          NaN
# 3328        3430 W Roosevelt Road   60624.0  5330444.0  NaN          NaN
# 3329          5242 W North Avenue   60639.0  2371444.0  NaN          NaN
# 3330           1631 E 71st Street   60649.0  4937500.0  NaN          NaN
# 3331           518 W 103rd Street   60628.0  2339445.0  NaN          NaN
# 3332             7 N Homan Avenue   60624.0  2653900.0  NaN          NaN
# 3333          3250 W Adams Street   60624.0  2650145.0  NaN          NaN
# 3334     3449 W Arthington Street   60624.0  6380773.0  NaN          NaN
# 3335        219 S Dearborn Street   60605.0  3538687.0  NaN          NaN
# 3336       932 W. Washington Blvd   60607.0  2267984.0  NaN          NaN
#
#      Length of Day IDHS Provider ID         ...          Executive Director  \
# 0     EXTENDED DAY              NaN         ...                         NaN
# 1     EXTENDED DAY              NaN         ...                         NaN
# 2     EXTENDED DAY              NaN         ...                         NaN
# 3     EXTENDED DAY              NaN         ...                         NaN
# 4     EXTENDED DAY              NaN         ...                         NaN
# 5     EXTENDED DAY              NaN         ...                         NaN
# 6     EXTENDED DAY              NaN         ...                         NaN
# 7     EXTENDED DAY              NaN         ...                         NaN
# 8     EXTENDED DAY              NaN         ...                         NaN
# 9     EXTENDED DAY              NaN         ...                         NaN
# 10    EXTENDED DAY              NaN         ...                         NaN
# 11    EXTENDED DAY              NaN         ...                         NaN
# 12    EXTENDED DAY              NaN         ...                         NaN
# 13    EXTENDED DAY              NaN         ...                         NaN
# 14    EXTENDED DAY              NaN         ...                         NaN
# 15    EXTENDED DAY              NaN         ...                         NaN
# 16    EXTENDED DAY              NaN         ...                         NaN
# 17    EXTENDED DAY              NaN         ...                         NaN
# 18    EXTENDED DAY              NaN         ...                         NaN
# 19    EXTENDED DAY              NaN         ...                         NaN
# 20    EXTENDED DAY              NaN         ...                         NaN
# 21    EXTENDED DAY              NaN         ...                         NaN
# 22    EXTENDED DAY              NaN         ...                         NaN
# 23    EXTENDED DAY              NaN         ...                         NaN
# 24    EXTENDED DAY              NaN         ...                         NaN
# 25    EXTENDED DAY              NaN         ...                         NaN
# 26    EXTENDED DAY              NaN         ...                         NaN
# 27    EXTENDED DAY              NaN         ...                         NaN
# 28    EXTENDED DAY              NaN         ...                         NaN
# 29    EXTENDED DAY              NaN         ...                         NaN
# ...            ...              ...         ...                         ...
# 3307           NaN              NaN         ...                         NaN
# 3308           NaN              NaN         ...                         NaN
# 3309           NaN              NaN         ...                         NaN
# 3310           NaN              NaN         ...                         NaN
# 3311           NaN              NaN         ...                         NaN
# 3312           NaN              NaN         ...                         NaN
# 3313           NaN              NaN         ...                         NaN
# 3314           NaN              NaN         ...                         NaN
# 3315           NaN              NaN         ...                         NaN
# 3316           NaN              NaN         ...                         NaN
# 3317           NaN              NaN         ...                         NaN
# 3318           NaN              NaN         ...                         NaN
# 3319           NaN              NaN         ...                         NaN
# 3320           NaN              NaN         ...                         NaN
# 3321           NaN              NaN         ...                         NaN
# 3322           NaN              NaN         ...                         NaN
# 3323           NaN              NaN         ...                         NaN
# 3324           NaN              NaN         ...                         NaN
# 3325           NaN              NaN         ...                         NaN
# 3326           NaN              NaN         ...                         NaN
# 3327           NaN              NaN         ...                         NaN
# 3328           NaN              NaN         ...                         NaN
# 3329           NaN              NaN         ...                         NaN
# 3330           NaN              NaN         ...                         NaN
# 3331           NaN              NaN         ...                         NaN
# 3332           NaN              NaN         ...                         NaN
# 3333           NaN              NaN         ...                         NaN
# 3334           NaN              NaN         ...                         NaN
# 3335           NaN              NaN         ...                         NaN
# 3336           NaN              NaN         ...                         NaN
#
#      Center Director ECE Available Programs NAEYC Valid Until  \
# 0                NaN                    NaN               NaN
# 1                NaN                    NaN               NaN
# 2                NaN                    NaN               NaN
# 3                NaN                    NaN               NaN
# 4                NaN                    NaN               NaN
# 5                NaN                    NaN               NaN
# 6                NaN                    NaN               NaN
# 7                NaN                    NaN               NaN
# 8                NaN                    NaN               NaN
# 9                NaN                    NaN               NaN
# 10               NaN                    NaN               NaN
# 11               NaN                    NaN               NaN
# 12               NaN                    NaN               NaN
# 13               NaN                    NaN               NaN
# 14               NaN                    NaN               NaN
# 15               NaN                    NaN               NaN
# 16               NaN                    NaN               NaN
# 17               NaN                    NaN               NaN
# 18               NaN                    NaN               NaN
# 19               NaN                    NaN               NaN
# 20               NaN                    NaN               NaN
# 21               NaN                    NaN               NaN
# 22               NaN                    NaN               NaN
# 23               NaN                    NaN               NaN
# 24               NaN                    NaN               NaN
# 25               NaN                    NaN               NaN
# 26               NaN                    NaN               NaN
# 27               NaN                    NaN               NaN
# 28               NaN                    NaN               NaN
# 29               NaN                    NaN               NaN
# ...              ...                    ...               ...
# 3307             NaN                    NaN               NaN
# 3308             NaN                    NaN               NaN
# 3309             NaN                    NaN               NaN
# 3310             NaN                    NaN               NaN
# 3311             NaN                    NaN               NaN
# 3312             NaN                    NaN               NaN
# 3313             NaN                    NaN               NaN
# 3314             NaN                    NaN               NaN
# 3315             NaN                    NaN               NaN
# 3316             NaN                    NaN               NaN
# 0                            NaN    NaN                  NaN
# 1                            NaN    NaN                  NaN
# 2                            NaN    NaN                  NaN
# 3                            NaN    NaN                  NaN
# 4                            NaN    NaN                  NaN
# 5                            NaN    NaN                  NaN
# 6                            NaN    NaN                  NaN
# 7                            NaN    NaN                  NaN
# 8                            NaN    NaN                  NaN
# 9                            NaN    NaN                  NaN
# 10                           NaN    NaN                  NaN
# 11                           NaN    NaN                  NaN
# 12                           NaN    NaN                  NaN
# 13                           NaN    NaN                  NaN
# 14                           NaN    NaN                  NaN
# 15                           NaN    NaN                  NaN
# 16                           NaN    NaN                  NaN
# 17                           NaN    NaN                  NaN
# 18                           NaN    NaN                  NaN
# 19                           NaN    NaN                  NaN
# 20                           NaN    NaN                  NaN
# 21                           NaN    NaN                  NaN
# 22                           NaN    NaN                  NaN
# 23                           NaN    NaN                  NaN
# 24                           NaN    NaN                  NaN
# 25                           NaN    NaN                  NaN
# 26                           NaN    NaN                  NaN
# 27                           NaN    NaN                  NaN
# 28                           NaN    NaN                  NaN
# 29                           NaN    NaN                  NaN
# ...                          ...    ...                  ...
# 3307                         NaN    NaN  Child Parent Center
# 3308                         NaN    NaN  Child Parent Center
# 3309                         NaN    NaN  Child Parent Center
# 3310                         NaN    NaN  Child Parent Center
# 3311                         NaN    NaN     Early Head Start
# 3312                         NaN    NaN     Early Head Start
# 3313                         NaN    NaN     Early Head Start
# 3314                         NaN    NaN     Early Head Start
# 3315                         NaN    NaN     Early Head Start
# 3316                         NaN    NaN     Early Head Start
# 3317                         NaN    NaN     Early Head Start
# 3318                         NaN    NaN     Early Head Start
# 3319                         NaN    NaN     Early Head Start
# 3320                         NaN    NaN     Early Head Start
# 3321                         NaN    NaN     Early Head Start
# 3322                         NaN    NaN     Early Head Start
# 3323                         NaN    NaN     Early Head Start
# 3324                         NaN    NaN     Early Head Start
# 3325                         NaN    NaN     Early Head Start
# 3326                         NaN    NaN     Early Head Start
# 3327                         NaN    NaN     Early Head Start
# 3328                         NaN    NaN     Early Head Start
# 3329                         NaN    NaN     Early Head Start
# 3330                         NaN    NaN     Early Head Start
# 3331                         NaN    NaN     Early Head Start
# 3332                         NaN    NaN     Early Head Start
# 3333                         NaN    NaN     Early Head Start
# 3334                         NaN    NaN     Early Head Start
# 3335                         NaN    NaN           Child Care
# 3336                         NaN    NaN     Early Head Start
#
# [3291 rows x 32 columns]

# %%
fields =['Site name','Address','Zip','Phone','Program Name']
data = sample_data[fields]
data_np = data.fillna(0).as_matrix()
a= ' '.join(list(map(lambda x:str(x),data_np[0]))).strip()
b= ' '.join(list(map(lambda x:str(x),data_np[1]))).strip()
b=b.replace("Ave","Avenue")
print(a,"\n",b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-86b4295d3cb0> in <module>()
#       1 fields =['Site name','Address','Zip','Phone','Program Name','Timestamp']
# ----> 2 data = sample_data[fields]
#       3 data_np = data.fillna(0).as_matrix()
#       4 a= ' '.join(list(map(lambda x:str(x),data_np[0]))).strip()
#       5 b= ' '.join(list(map(lambda x:str(x),data_np[1]))).strip()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
# -> 2097             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2098             return self.take(indexer, axis=1, convert=True)
#    2099
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1227                 mask = check == -1
#    1228                 if mask.any():
# -> 1229                     raise KeyError('%s not in index' % objarr[mask])
#    1230
#    1231                 return _values_from_object(indexer)
#
# KeyError: "['Timestamp'] not in index"

# %%
cosine_sim(a,b)
# Out:
# 0.8680942667801238

# %%
# Generate Fake Data 
import random
from datetime import datetime
mfgs = ["A","B","C","D","E","F"]
zones = ["S","W","E","N","C"]
dims = ["Small","Medium","Large"]
price = lambda :random.randrange(10000,100000)
idim = lambda : random.randrange(2)
qty = lambda : random.randrange(100,10000)
wt = lambda : random.randrange(10,100000)
imfg = lambda :random.randrange(len(mfgs))
iz = lambda :random.randrange(len(zones))
description = "This is iron"
zone = lambda : ranomd.randrange(5)
fields = ["PLN", "Item","Price", "Dim","Qty", "Mfg", "Type","Weight", "Description","Zone","TimeStamp"]
iron = pd.DataFrame(columns=fields)
row =["IR","IRON", price(),dims[idim()],qty(),mfgs[imfg()],"Iron",wt(),description,zones[iz()],datetime.now()]
for i in range(1,400):
    row =["IR","IRON", price(),dims[idim()],qty(),mfgs[imfg()],"Iron",wt(),description,zones[iz()],datetime.now()]
    row[0]+=str(i)
    row[1]+="_"+str(i)
    iron.loc[i]=row

# %%
iron.head()
# Out:
#    PLN    Item    Price     Dim     Qty Mfg  Type   Weight   Description Zone  \
# 1  IR1  IRON_1  97234.0  Medium  5798.0   C  Iron  96041.0  This is iron    W
# 2  IR2  IRON_2  59211.0  Medium  6930.0   C  Iron  30525.0  This is iron    S
# 3  IR3  IRON_3  32979.0   Small  9401.0   B  Iron   5219.0  This is iron    C
# 4  IR4  IRON_4  92052.0   Small  3023.0   A  Iron  36487.0  This is iron    E
# 5  IR5  IRON_5  62218.0   Small  8982.0   F  Iron  50165.0  This is iron    W
#
#                    TimeStamp
# 1 2017-04-01 19:23:22.965843
# 2 2017-04-01 19:23:22.969981
# 3 2017-04-01 19:23:22.974053
# 4 2017-04-01 19:23:22.980320
# 5 2017-04-01 19:23:22.985774

# %%
#generate fake glass
import random
from datetime import datetime
item_type = "Glass"
mfgs = ["A","B","C","D","E","F"]
zones = ["S","W","E","N","C"]
dims = ["Small","Medium","Large"]
price = lambda :random.randrange(10000,100000)
idim = lambda : random.randrange(2)
qty = lambda : random.randrange(100,10000)
wt = lambda : random.randrange(10,100000)
imfg = lambda :random.randrange(len(mfgs))
iz = lambda :random.randrange(len(zones))
description = "This is glass"
zone = lambda : ranomd.randrange(5)
fields = ["PLN", "Item","Price", "Dim","Qty", "Mfg", "Type","Weight", "Description","Zone","TimeStamp"]
glass = pd.DataFrame(columns=fields)
# row =["IR",, price(),dims[idim()],qty(),mfgs[imfg()],item_type,wt(),description,zones[iz()],datetime.now()]
for i in range(400,800):
    row =["IR",item_type.upper(), price(),dims[idim()],qty(),mfgs[imfg()],item_type,wt(),description,zones[iz()],datetime.now()]
    row[0]+=str(i)
    row[1]+="_"+str(i)
    glass.loc[i]=row
glass
# Out:
#        PLN       Item    Price     Dim     Qty Mfg   Type   Weight  \
# 400  IR400  GLASS_400  20675.0  Medium  6354.0   F  Glass  27467.0
# 401  IR401  GLASS_401  80112.0  Medium  8416.0   A  Glass     39.0
# 402  IR402  GLASS_402  53007.0   Small  4224.0   B  Glass  83020.0
# 403  IR403  GLASS_403  39935.0   Small  7709.0   D  Glass  36057.0
# 404  IR404  GLASS_404  81078.0   Small  8573.0   D  Glass  36558.0
# 405  IR405  GLASS_405  81263.0  Medium  2191.0   B  Glass   7247.0
# 406  IR406  GLASS_406  15498.0   Small  7302.0   F  Glass  25284.0
# 407  IR407  GLASS_407  43233.0   Small  8535.0   E  Glass  93853.0
# 408  IR408  GLASS_408  39157.0  Medium  7108.0   F  Glass  75795.0
# 409  IR409  GLASS_409  62074.0  Medium  4398.0   B  Glass  18335.0
# 410  IR410  GLASS_410  30539.0  Medium  1189.0   F  Glass  63678.0
# 411  IR411  GLASS_411  50675.0  Medium  8325.0   C  Glass   6141.0
# 412  IR412  GLASS_412  74591.0  Medium  9621.0   B  Glass  40900.0
# 413  IR413  GLASS_413  22091.0   Small  1542.0   E  Glass  21752.0
# 414  IR414  GLASS_414  64168.0  Medium  3357.0   A  Glass   6802.0
# 415  IR415  GLASS_415  50052.0  Medium  4106.0   B  Glass  41534.0
# 416  IR416  GLASS_416  28271.0   Small  1863.0   E  Glass  89368.0
# 417  IR417  GLASS_417  55130.0  Medium  3300.0   B  Glass  79777.0
# 418  IR418  GLASS_418  94070.0  Medium  6505.0   B  Glass  96909.0
# 419  IR419  GLASS_419  27493.0   Small  8964.0   E  Glass   2574.0
# 420  IR420  GLASS_420  61843.0   Small  1400.0   D  Glass   9126.0
# 421  IR421  GLASS_421  98913.0   Small  4121.0   D  Glass  24454.0
# 422  IR422  GLASS_422  91279.0  Medium  6316.0   F  Glass  24415.0
# 423  IR423  GLASS_423  60184.0  Medium  6474.0   B  Glass  75425.0
# 424  IR424  GLASS_424  25224.0   Small  2345.0   A  Glass  84277.0
# 425  IR425  GLASS_425  59439.0   Small  2507.0   D  Glass  69821.0
# 426  IR426  GLASS_426  44270.0   Small  9287.0   E  Glass  39865.0
# 427  IR427  GLASS_427  85183.0  Medium  2569.0   E  Glass  56099.0
# 428  IR428  GLASS_428  94799.0   Small  1629.0   E  Glass  40289.0
# 429  IR429  GLASS_429  12003.0   Small  7523.0   F  Glass  45035.0
# ..     ...        ...      ...     ...     ...  ..    ...      ...
# 770  IR770  GLASS_770  72631.0   Small  5886.0   E  Glass  42335.0
iz = lambda :random.randrange(len(zones))
description = "This is Accessories"
zone = lambda : ranomd.randrange(5)
fields = ["PLN", "Item","Price", "Dim","Qty", "Mfg", "Type","Weight", "Description","Zone","TimeStamp"]
acc = pd.DataFrame(columns=fields)
# row =["IR",, price(),dims[idim()],qty(),mfgs[imfg()],item_type,wt(),description,zones[iz()],datetime.now()]
for i in range(800,1200):
    row =["IR",item_type.upper(), price(),dims[idim()],qty(),mfgs[imfg()],item_type,wt(),description,zones[iz()],datetime.now()]
    row[0]+=str(i)
    row[1]+="_"+str(i)
    acc.loc[i]=row
acc.head()
# Out:
#        PLN             Item    Price     Dim     Qty Mfg         Type  \
# 800  IR800  ACCESSORIES_800  66655.0  Medium  6448.0   B  Accessories
# 801  IR801  ACCESSORIES_801  36823.0  Medium  4545.0   D  Accessories
# 802  IR802  ACCESSORIES_802  22695.0   Small  4510.0   D  Accessories
# 803  IR803  ACCESSORIES_803  73840.0   Small  2665.0   C  Accessories
# 804  IR804  ACCESSORIES_804  21273.0  Medium  7435.0   F  Accessories
#
#       Weight          Description Zone                  TimeStamp
# 800   3888.0  This is Accessories    W 2017-04-01 19:23:39.845296
# 801  65984.0  This is Accessories    S 2017-04-01 19:23:39.849148
# 802   1882.0  This is Accessories    W 2017-04-01 19:23:39.853290
# 803   5684.0  This is Accessories    S 2017-04-01 19:23:39.857320
# 804  96653.0  This is Accessories    C 2017-04-01 19:23:39.864052

# %%
glass.head()
# Out:
#        PLN   Item    Price    Dim     Qty Mfg   Type   Weight    Description  \
# 400  IR400  GLASS  76739.0  Small  7730.0   D  Glass  80807.0  This is glass
# 401  IR401  GLASS  49340.0  Small  2477.0   F  Glass  32729.0  This is glass
# 402  IR402  GLASS  12082.0  Small  3327.0   F  Glass   1171.0  This is glass
# 403  IR403  GLASS  57122.0  Small  6541.0   B  Glass  92409.0  This is glass
# 404  IR404  GLASS  37134.0  Small  6707.0   B  Glass  21873.0  This is glass
#
#     Zone                  TimeStamp
# 400    N 2017-04-01 19:06:14.382292
# 401    C 2017-04-01 19:06:14.386162
# 402    W 2017-04-01 19:06:14.390628
# 403    N 2017-04-01 19:06:14.394786
# 404    N 2017-04-01 19:06:14.399479

# %%
def dump_to_json(file_name,data):
    import json
    with open(file_name, 'w') as outfile:
        json.dump(data, outfile,indent=4)

# %%
iron.TimeStamp= iron.TimeStamp.apply(lambda x:str(x))
iron_matrix = iron.as_matrix()
iron_list = [dict(list(zip(fields,item))) for item in iron_matrix]
dump_to_json("iron.json",iron_list)

# %%
glass.TimeStamp= glass.TimeStamp.apply(lambda x:str(x))
glass_matrix = glass.as_matrix()
glass_list = [dict(list(zip(fields,item))) for item in glass_matrix]
dump_to_json("glass.json",glass_list)

# %%
acc.TimeStamp= acc.TimeStamp.apply(lambda x:str(x))
acc_matrix = acc.as_matrix()
acc_list = [dict(list(zip(fields,item))) for item in acc_matrix]
dump_to_json("acc.json",acc_list)
